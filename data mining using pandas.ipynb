# %%
#Step 1. Import the necessary libraries

import pandas as pd
from numpy import nan as NA

# %%
#Step 2. Import the dataset Euro_2012_stats_TEAM
#Step 3. Assign it to a variable called euro12.¶

euro12= pd.read_csv("Desktop/Euro_2012_stats_TEAM.csv")
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 4. Select only the Goal column.

print(euro12.loc[0:15,['Goals']])
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %%
#Step 5. How many team participated in the Euro2012?

leng = euro12.dropna(how='all')
print(len(leng)-1)
# Out:
# 16

# %%
## Step 6. What is the number of columns in the dataset?

print(len(euro12.columns))
# Out:
# 35

# %%
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

discipline = euro12.loc[:15,['Team', 'Yellow Cards','Red Cards']]
print(discipline)
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
## step 8 Sort the teams by Red Cards, then to Yellow Cards

print(discipline.sort_values(['Red Cards','Yellow Cards'],ascending = False))
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece           9.0        1.0
# 9                Poland           7.0        1.0
# 11  Republic of Ireland           6.0        1.0
# 7                 Italy          16.0        0.0
# 10             Portugal          12.0        0.0
# 13                Spain          11.0        0.0
# 0               Croatia           9.0        0.0
# 1        Czech Republic           7.0        0.0
# 14               Sweden           7.0        0.0
# 4                France           6.0        0.0
# 12               Russia           6.0        0.0
# 3               England           5.0        0.0
# 8           Netherlands           5.0        0.0
# 15              Ukraine           5.0        0.0
# 2               Denmark           4.0        0.0
# 5               Germany           4.0        0.0

# %%
# Step 9. Calculate the mean Yellow Cards given per Team
print(discipline.loc[0:15,['Yellow Cards']].mean())
# Out:
# Yellow Cards    7.461538
# dtype: float64

# %%
# Step 10. Filter teams that scored more than 6 goals
con = euro12['Goals']>6
print(euro12[con])
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany   10.0             32.0              32.0            47.80%
# 13    Spain   12.0             42.0              33.0            55.90%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.60%                        80.0           2.0            1.0
# 13           16.00%                       100.0           0.0            1.0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                    0.0  ...        10.0                62.60%       63.0
# 13                   0.0  ...        15.0                93.80%      102.0
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5            49.0      12.0           4.0        0.0     15.0      15.0
# 13           83.0      19.0          11.0        0.0     17.0      17.0
#
#     Players Used
# 5           17.0
# 13          18.0
#
# ...

# %%
###  Step 11. Select the teams that start with G
leng = euro12.dropna(how='all')
name = leng.Team.str.contains('^G')
print(leng['Team'][name])
# Out:
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %%
###Step 12. Select the first 7 columns
print(euro12.columns[:7])
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)'],
#       dtype='object')

# %%
##Step 13. Select all columns except the last 3.
print(euro12.columns[:-3])
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards'],
#       dtype='object')

# %%
Step 14. Present only the Shooting Accuracy from England, Italy and Russia
df2 = euro12.set_index('Team')
print(df2.loc[['England', 'Italy','Russia'],['Shooting Accuracy']])
# Out:
#         Shooting Accuracy
# Team
# England            50.00%
# Italy              43.00%
# Russia             22.50%

# %%
#####       Step 15. Use apply method on Goal Column to make a new column called Performance, using following conditions
###            If Goals are less than or equal to 2, peformance is Below Avg
###            If Goals are more than 2 and less than or equal to 5, peformance is Average
###            If Goals are more than 5 and less than or equal to 10, peformance is Above Average
###            If Goals are more than 10 then peformance is Excellent
def algo(goals):
    if goals <= 2:
        return "below average"
    elif goals <=5:
        return "average"
    elif goals <= 10:
        return "above average"
    elif goals>5 or goals<=10:
        return "excllent"
new= euro12['Goals'].apply(algo)
new
# Out:
# 0           average
# 1           average
# 2           average
# 3           average
# 4           average
# 5     above average
# 6           average
# 7     above average
# 8     below average
# 9     below average
# 10    above average
# 11    below average
# 12          average
# 13         excllent
# 14          average
# 15    below average
# 16             None
# 17             None
# 18             None
# 19             None
# Name: Goals, dtype: object
